# %%
from imagecluster import calc, io as icio, postproc
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 from imagecluster import calc, io as icio, postproc
#
# File ~/Programming/projects/fyp_playground/Dataset_clustering/imagecluster_elctro/imagecluster/calc.py:9
#       6 from scipy.cluster import hierarchy
#       7 from sklearn.decomposition import PCA
# ----> 9 from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
#      10 from tensorflow.keras.models import Model
#      13 pj = os.path.join
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/__init__.py:37
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/__init__.py:99
#      96 from tensorflow.python.lib.io import python_io
#      98 # Make some application and test modules available.
# ---> 99 from tensorflow.python.platform import app
#     100 from tensorflow.python.platform import flags
#     101 from tensorflow.python.platform import gfile
#
# File ~/.local/lib/python3.10/site-packages/tensorflow/python/platform/app.py:19
#      16 """Generic entry point script."""
#      17 import sys as _sys
# ---> 19 from absl.app import run as _run
#      21 from tensorflow.python.platform import flags
#      22 from tensorflow.python.util.tf_export import tf_export
#
# ImportError: cannot import name 'run' from 'absl.app' (/home/nitin/.local/lib/python3.10/site-packages/absl/app.py)

# %%
image_path = '../final_dataset/input1'
cluster_path = '../final_dataset/imagecluster/clusters/'
# The bottleneck is calc.fingerprints() called in this function, all other
# operations are very fast. get_image_data() writes fingerprints to disk and
# loads them again instead of re-calculating them.
images,fingerprints,timestamps = icio.get_image_data(image_path)

# Run clustering on the fingerprints. Select clusters with similarity index
# sim=0.5.
clusters = calc.cluster(fingerprints, sim=0.5, timestamps=timestamps, alpha=0.4)

# Create dirs with links to images. Dirs represent the clusters the images
# belong to.
postproc.make_links(clusters, cluster_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 6
#       2 cluster_path = '../final_dataset/imagecluster/clusters/'
#       3 # The bottleneck is calc.fingerprints() called in this function, all other
#       4 # operations are very fast. get_image_data() writes fingerprints to disk and
#       5 # loads them again instead of re-calculating them.
# ----> 6 images,fingerprints,timestamps = icio.get_image_data(image_path)
#       8 # Run clustering on the fingerprints. Select clusters with similarity index
#       9 # sim=0.5.
#      10 clusters = calc.cluster(fingerprints, sim=0.5, timestamps=timestamps, alpha=0.4)
#
# NameError: name 'icio' is not defined

# %%
# Plot images arranged in clusters.
postproc.visualize(clusters, images)
# Out:
# plot array (uint8) size: 12.05859375 MiB
